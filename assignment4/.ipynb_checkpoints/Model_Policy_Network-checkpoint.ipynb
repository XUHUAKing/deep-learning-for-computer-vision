# %% [markdown]
# # Model-Based RL
# In this exercise you will implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem.

# %% [markdown]
# What is a model and why would we want to use one? In this case, a model is going to be a neural network that attempts to learn the dynamics of the real environment. For example, in the CartPole we would like a model to be able to predict the next position of the Cart given the previous position and an action. By learning an accurate model, we can train our agent using the model rather than requiring to use the real environment every time. While this may seem less useful when the real environment is itself a simulation, like in our CartPole task, it can have huge advantages when attempting to learn policies for acting in the physical world.

# %% [markdown]
# How are we going to accomplish this in Tensorflow? We are going to be using a neural network that will learn the transition dynamics between a previous observation and action, and the expected new observation, reward, and done state. Our training procedure will involve switching between training our model using the real environment, and training our agent’s policy using the model environment. By using this approach we will be able to learn a policy that allows our agent to solve the CartPole task without actually ever training the policy on the real environment!

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters
H = 30 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 5 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################
loglik = input_y*tf.log(probability) + (1 - input_y)*tf.log(1-probability)
loss = -tf.reduce_mean(loglik * advantages)
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer

def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################
    discount_reward = np.zeros_like(r)
    running_rewards = 0  
    for i in reversed(range(r.size)):
        running_rewards = running_rewards*gamma + r[i]
        discount_reward[i] = running_rewards
    
    return discount_reward
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                
                ################################################################################
                # TODO: Run the model network and compute predicted_state                      #
                # Output: 'pState'                                                             #
                ################################################################################
                #the first reward, done, and the last action is useless
                #the movement are continuous in one episode
                actions = np.array(epy[:-1])
                state_prevs = epx[:-1,:]
                state_prevs = np.hstack([state_prevs,actions])
                state_nexts = epx[1:,:]
                rewards = np.array(epr[1:,:])
                dones = np.array(epd[1:,:])
                state_nextsAll = np.hstack([state_nexts,rewards,dones])

                feed_dict={previous_state: state_prevs, true_observation: state_nexts,true_done:dones,true_reward:rewards}
                loss,pState,_ = sess.run([model_loss,predicted_state,updateModel],feed_dict)

                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                

            if trainThePolicy == True:
                
                ################################################################################
                # TODO: Run the policy network and compute newGrads                            #
                # Output: 'tGrad'                                                              #
                ################################################################################
                discounted_epr = discount_rewards(epr)
                # size the rewards to be unit normal (helps control the gradient estimator variance)
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr //= np.std(discounted_epr)
                              
                tGrad = sess.run(newGrads,feed_dict = {observations:epx, input_y:epy, advantages:discounted_epr})
    
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    
                    ################################################################################
                    # TODO:                                                                        #
                    # (1) Run the policy network and update gradients                              #
                    # (2) Reset gradBuffer to 0                                                    #
                    ################################################################################           
                    sess.run(updateGrads,feed_dict={W1Grad: gradBuffer[0],W2Grad:gradBuffer[1]})
                    #set gradBuffer to 0
                    for ix,grad in enumerate(gradBuffer):
                        gradBuffer[ix] = grad * 0            
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################

                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size > 200:
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes
                if episode_number > 100:
                    
                    ################################################################################
                    # TODO: Alternating between training the policy from the model and training    #
                    # the model from the real environment.                                         #
                    ################################################################################
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 19.333333. action: 1.000000. mean reward 19.333333.
# World Perf: Episode 7.000000. Reward 21.666667. action: 1.000000. mean reward 19.356667.
# World Perf: Episode 10.000000. Reward 24.333333. action: 0.000000. mean reward 19.406433.
# World Perf: Episode 13.000000. Reward 13.333333. action: 0.000000. mean reward 19.345702.
# World Perf: Episode 16.000000. Reward 24.333333. action: 1.000000. mean reward 19.395579.
# World Perf: Episode 19.000000. Reward 19.333333. action: 1.000000. mean reward 19.394956.
# World Perf: Episode 22.000000. Reward 30.666667. action: 1.000000. mean reward 19.507673.
# World Perf: Episode 25.000000. Reward 15.000000. action: 0.000000. mean reward 19.462597.
# World Perf: Episode 28.000000. Reward 15.000000. action: 1.000000. mean reward 19.417971.
# World Perf: Episode 31.000000. Reward 24.000000. action: 0.000000. mean reward 19.463791.
# World Perf: Episode 34.000000. Reward 18.333333. action: 0.000000. mean reward 19.452486.
# World Perf: Episode 37.000000. Reward 19.666667. action: 0.000000. mean reward 19.454628.
# World Perf: Episode 40.000000. Reward 21.000000. action: 0.000000. mean reward 19.470082.
# World Perf: Episode 43.000000. Reward 21.000000. action: 1.000000. mean reward 19.485381.
# World Perf: Episode 46.000000. Reward 17.666667. action: 0.000000. mean reward 19.467194.
# World Perf: Episode 49.000000. Reward 20.333333. action: 0.000000. mean reward 19.475855.
# World Perf: Episode 52.000000. Reward 30.666667. action: 0.000000. mean reward 19.587763.
# World Perf: Episode 55.000000. Reward 21.666667. action: 0.000000. mean reward 19.608552.
# World Perf: Episode 58.000000. Reward 16.333333. action: 0.000000. mean reward 19.575800.
# World Perf: Episode 61.000000. Reward 21.666667. action: 0.000000. mean reward 19.596709.
# World Perf: Episode 64.000000. Reward 19.333333. action: 1.000000. mean reward 19.594075.
# World Perf: Episode 67.000000. Reward 22.000000. action: 0.000000. mean reward 19.618134.
# World Perf: Episode 70.000000. Reward 27.333333. action: 0.000000. mean reward 19.695286.
# World Perf: Episode 73.000000. Reward 19.333333. action: 0.000000. mean reward 19.691667.
# World Perf: Episode 76.000000. Reward 18.000000. action: 0.000000. mean reward 19.674750.
# World Perf: Episode 79.000000. Reward 21.333333. action: 1.000000. mean reward 19.691336.
# World Perf: Episode 82.000000. Reward 26.333333. action: 0.000000. mean reward 19.757756.
# World Perf: Episode 85.000000. Reward 26.000000. action: 1.000000. mean reward 19.820178.
# World Perf: Episode 88.000000. Reward 37.666667. action: 1.000000. mean reward 19.998643.
# World Perf: Episode 91.000000. Reward 38.666667. action: 0.000000. mean reward 20.185324.
# World Perf: Episode 94.000000. Reward 25.333333. action: 1.000000. mean reward 20.236804.
# World Perf: Episode 97.000000. Reward 14.333333. action: 1.000000. mean reward 20.177769.
# World Perf: Episode 100.000000. Reward 27.333333. action: 1.000000. mean reward 20.249325.
# World Perf: Episode 103.000000. Reward 24.000000. action: 0.000000. mean reward 20.286831.
# World Perf: Episode 106.000000. Reward 18.000000. action: 1.000000. mean reward 20.164476.
# World Perf: Episode 109.000000. Reward 13.666667. action: 0.000000. mean reward 20.053324.
# World Perf: Episode 112.000000. Reward 29.000000. action: 0.000000. mean reward 21.226389.
# World Perf: Episode 115.000000. Reward 14.666667. action: 1.000000. mean reward 22.415251.
# World Perf: Episode 118.000000. Reward 20.333333. action: 0.000000. mean reward 22.612791.
# World Perf: Episode 121.000000. Reward 16.000000. action: 1.000000. mean reward 22.408567.
# World Perf: Episode 124.000000. Reward 34.333333. action: 0.000000. mean reward 22.371941.
# World Perf: Episode 127.000000. Reward 29.000000. action: 0.000000. mean reward 22.284966.
# World Perf: Episode 130.000000. Reward 22.000000. action: 1.000000. mean reward 22.337843.
# World Perf: Episode 133.000000. Reward 30.000000. action: 1.000000. mean reward 24.506285.
# World Perf: Episode 136.000000. Reward 24.000000. action: 0.000000. mean reward 24.456213.
# World Perf: Episode 139.000000. Reward 22.333333. action: 0.000000. mean reward 24.279261.
# World Perf: Episode 142.000000. Reward 22.333333. action: 0.000000. mean reward 24.131113.
# World Perf: Episode 145.000000. Reward 23.000000. action: 0.000000. mean reward 24.011406.
# World Perf: Episode 148.000000. Reward 20.333333. action: 0.000000. mean reward 23.870537.
# World Perf: Episode 151.000000. Reward 19.000000. action: 0.000000. mean reward 28.043533.
# World Perf: Episode 154.000000. Reward 15.666667. action: 1.000000. mean reward 27.914309.
# World Perf: Episode 157.000000. Reward 28.000000. action: 1.000000. mean reward 28.459969.
# World Perf: Episode 160.000000. Reward 42.333333. action: 0.000000. mean reward 29.355042.
# World Perf: Episode 163.000000. Reward 19.000000. action: 0.000000. mean reward 30.860367.
# World Perf: Episode 166.000000. Reward 15.333333. action: 1.000000. mean reward 30.464279.
# World Perf: Episode 169.000000. Reward 35.333333. action: 0.000000. mean reward 30.449690.
# World Perf: Episode 172.000000. Reward 17.000000. action: 0.000000. mean reward 30.143637.
# World Perf: Episode 175.000000. Reward 16.000000. action: 0.000000. mean reward 29.808767.
# World Perf: Episode 178.000000. Reward 20.666667. action: 0.000000. mean reward 29.559790.
# World Perf: Episode 181.000000. Reward 33.333333. action: 0.000000. mean reward 29.364889.
# World Perf: Episode 184.000000. Reward 21.666667. action: 0.000000. mean reward 29.128736.
# World Perf: Episode 187.000000. Reward 26.000000. action: 0.000000. mean reward 28.928728.
# World Perf: Episode 190.000000. Reward 21.666667. action: 1.000000. mean reward 28.678106.
# World Perf: Episode 193.000000. Reward 35.666667. action: 0.000000. mean reward 28.615503.
# World Perf: Episode 196.000000. Reward 39.333333. action: 1.000000. mean reward 28.539841.
# World Perf: Episode 199.000000. Reward 27.000000. action: 0.000000. mean reward 28.374613.
# World Perf: Episode 202.000000. Reward 20.333333. action: 1.000000. mean reward 28.141874.
# World Perf: Episode 205.000000. Reward 29.666667. action: 1.000000. mean reward 28.140257.
# World Perf: Episode 208.000000. Reward 26.000000. action: 0.000000. mean reward 27.992043.
# World Perf: Episode 211.000000. Reward 21.000000. action: 0.000000. mean reward 27.772772.
# World Perf: Episode 214.000000. Reward 15.000000. action: 1.000000. mean reward 27.433876.
# World Perf: Episode 217.000000. Reward 23.000000. action: 0.000000. mean reward 27.237722.
# World Perf: Episode 220.000000. Reward 25.333333. action: 1.000000. mean reward 27.170622.
# World Perf: Episode 223.000000. Reward 27.666667. action: 1.000000. mean reward 27.042257.
# World Perf: Episode 226.000000. Reward 26.000000. action: 0.000000. mean reward 26.873404.
# World Perf: Episode 229.000000. Reward 20.000000. action: 0.000000. mean reward 26.696917.
# World Perf: Episode 232.000000. Reward 29.333333. action: 0.000000. mean reward 26.769426.
# World Perf: Episode 235.000000. Reward 38.666667. action: 1.000000. mean reward 28.299255.
# World Perf: Episode 238.000000. Reward 31.333333. action: 0.000000. mean reward 28.624962.
# World Perf: Episode 241.000000. Reward 27.333333. action: 1.000000. mean reward 28.428152.
# World Perf: Episode 244.000000. Reward 33.333333. action: 0.000000. mean reward 28.946657.
# World Perf: Episode 247.000000. Reward 34.666667. action: 0.000000. mean reward 28.843643.
# World Perf: Episode 250.000000. Reward 32.333333. action: 0.000000. mean reward 28.687792.
# World Perf: Episode 253.000000. Reward 18.666667. action: 1.000000. mean reward 28.461271.
# World Perf: Episode 256.000000. Reward 37.666667. action: 1.000000. mean reward 28.439445.
# World Perf: Episode 259.000000. Reward 39.000000. action: 1.000000. mean reward 28.383348.
# World Perf: Episode 262.000000. Reward 26.333333. action: 1.000000. mean reward 28.273315.
# World Perf: Episode 265.000000. Reward 25.333333. action: 0.000000. mean reward 28.120934.
# World Perf: Episode 268.000000. Reward 27.000000. action: 1.000000. mean reward 27.966675.
# World Perf: Episode 271.000000. Reward 28.666667. action: 0.000000. mean reward 27.842493.
# World Perf: Episode 274.000000. Reward 59.666667. action: 0.000000. mean reward 28.145119.
# World Perf: Episode 277.000000. Reward 28.666667. action: 0.000000. mean reward 28.092169.
# World Perf: Episode 280.000000. Reward 36.333333. action: 0.000000. mean reward 28.026327.
# World Perf: Episode 283.000000. Reward 44.333333. action: 0.000000. mean reward 27.981562.
# World Perf: Episode 286.000000. Reward 31.666667. action: 0.000000. mean reward 27.846825.
# World Perf: Episode 289.000000. Reward 37.666667. action: 0.000000. mean reward 29.866987.
# World Perf: Episode 292.000000. Reward 21.333333. action: 1.000000. mean reward 29.572655.
# World Perf: Episode 295.000000. Reward 35.666667. action: 0.000000. mean reward 29.452652.
# World Perf: Episode 298.000000. Reward 50.333333. action: 1.000000. mean reward 29.475410.
# World Perf: Episode 301.000000. Reward 64.666667. action: 0.000000. mean reward 29.667227.
# World Perf: Episode 304.000000. Reward 27.666667. action: 1.000000. mean reward 29.434509.
# World Perf: Episode 307.000000. Reward 32.000000. action: 1.000000. mean reward 29.234934.
# World Perf: Episode 310.000000. Reward 42.333333. action: 1.000000. mean reward 29.132635.
# World Perf: Episode 313.000000. Reward 47.666667. action: 1.000000. mean reward 29.124426.
# World Perf: Episode 316.000000. Reward 39.333333. action: 0.000000. mean reward 29.013968.
# World Perf: Episode 319.000000. Reward 34.000000. action: 1.000000. mean reward 28.874056.
# World Perf: Episode 322.000000. Reward 36.333333. action: 1.000000. mean reward 28.980516.
# World Perf: Episode 325.000000. Reward 40.666667. action: 1.000000. mean reward 29.092880.
# World Perf: Episode 328.000000. Reward 58.666667. action: 0.000000. mean reward 29.199369.
# World Perf: Episode 331.000000. Reward 53.666667. action: 0.000000. mean reward 29.257120.
# World Perf: Episode 334.000000. Reward 38.333333. action: 1.000000. mean reward 29.141403.
# World Perf: Episode 337.000000. Reward 31.333333. action: 1.000000. mean reward 29.194557.
# World Perf: Episode 340.000000. Reward 62.000000. action: 1.000000. mean reward 29.419310.
# World Perf: Episode 343.000000. Reward 28.333333. action: 0.000000. mean reward 29.370070.
# World Perf: Episode 346.000000. Reward 47.333333. action: 0.000000. mean reward 29.696882.
# World Perf: Episode 349.000000. Reward 32.000000. action: 0.000000. mean reward 29.503227.
# World Perf: Episode 352.000000. Reward 43.000000. action: 1.000000. mean reward 29.464697.
# World Perf: Episode 355.000000. Reward 36.000000. action: 0.000000. mean reward 29.508429.
# World Perf: Episode 358.000000. Reward 47.666667. action: 1.000000. mean reward 29.719332.
# World Perf: Episode 361.000000. Reward 39.666667. action: 1.000000. mean reward 29.679482.
# World Perf: Episode 364.000000. Reward 46.333333. action: 1.000000. mean reward 29.614138.
# World Perf: Episode 367.000000. Reward 59.666667. action: 1.000000. mean reward 29.724684.
# World Perf: Episode 370.000000. Reward 39.000000. action: 1.000000. mean reward 29.599607.
# World Perf: Episode 373.000000. Reward 28.000000. action: 0.000000. mean reward 29.360479.
# World Perf: Episode 376.000000. Reward 36.000000. action: 1.000000. mean reward 29.268623.
# World Perf: Episode 379.000000. Reward 42.333333. action: 1.000000. mean reward 29.198227.
# World Perf: Episode 382.000000. Reward 32.666667. action: 0.000000. mean reward 28.998491.
# World Perf: Episode 385.000000. Reward 43.666667. action: 0.000000. mean reward 28.944971.
# World Perf: Episode 388.000000. Reward 53.666667. action: 0.000000. mean reward 29.000313.
# World Perf: Episode 391.000000. Reward 26.333333. action: 1.000000. mean reward 28.775290.
# World Perf: Episode 394.000000. Reward 40.000000. action: 1.000000. mean reward 28.699400.
# World Perf: Episode 397.000000. Reward 52.000000. action: 1.000000. mean reward 28.801926.
# World Perf: Episode 400.000000. Reward 54.000000. action: 0.000000. mean reward 28.853027.
# World Perf: Episode 403.000000. Reward 49.000000. action: 1.000000. mean reward 29.919901.
# World Perf: Episode 406.000000. Reward 65.333333. action: 1.000000. mean reward 31.096016.
# World Perf: Episode 409.000000. Reward 48.666667. action: 0.000000. mean reward 31.120064.
# World Perf: Episode 412.000000. Reward 61.333333. action: 0.000000. mean reward 31.190271.
# World Perf: Episode 415.000000. Reward 43.000000. action: 1.000000. mean reward 31.060587.
# World Perf: Episode 418.000000. Reward 47.666667. action: 0.000000. mean reward 30.964041.
# World Perf: Episode 421.000000. Reward 73.666667. action: 0.000000. mean reward 31.232347.
# World Perf: Episode 424.000000. Reward 43.333333. action: 1.000000. mean reward 31.230398.
# World Perf: Episode 427.000000. Reward 42.000000. action: 1.000000. mean reward 31.168669.
# World Perf: Episode 430.000000. Reward 42.333333. action: 1.000000. mean reward 34.397324.
# World Perf: Episode 433.000000. Reward 55.666667. action: 0.000000. mean reward 36.440098.
# World Perf: Episode 436.000000. Reward 47.000000. action: 0.000000. mean reward 36.350288.
# World Perf: Episode 439.000000. Reward 41.000000. action: 1.000000. mean reward 36.546448.
# World Perf: Episode 442.000000. Reward 41.666667. action: 1.000000. mean reward 36.422527.
# World Perf: Episode 445.000000. Reward 48.666667. action: 1.000000. mean reward 36.289265.
# World Perf: Episode 448.000000. Reward 52.666667. action: 1.000000. mean reward 36.207981.
# World Perf: Episode 451.000000. Reward 82.666667. action: 1.000000. mean reward 36.438995.
# World Perf: Episode 454.000000. Reward 45.666667. action: 1.000000. mean reward 36.269878.
# World Perf: Episode 457.000000. Reward 41.333333. action: 0.000000. mean reward 36.025768.
# World Perf: Episode 460.000000. Reward 66.333333. action: 0.000000. mean reward 36.086227.
# World Perf: Episode 463.000000. Reward 46.000000. action: 1.000000. mean reward 35.915798.
# World Perf: Episode 466.000000. Reward 126.333333. action: 1.000000. mean reward 36.556423.
# World Perf: Episode 469.000000. Reward 85.000000. action: 0.000000. mean reward 36.778942.
# World Perf: Episode 472.000000. Reward 59.000000. action: 1.000000. mean reward 36.794212.
# World Perf: Episode 475.000000. Reward 50.000000. action: 1.000000. mean reward 36.696239.
# World Perf: Episode 478.000000. Reward 50.000000. action: 1.000000. mean reward 36.639355.
# World Perf: Episode 481.000000. Reward 59.333333. action: 1.000000. mean reward 36.619518.
# World Perf: Episode 484.000000. Reward 62.333333. action: 0.000000. mean reward 36.644066.
# World Perf: Episode 487.000000. Reward 56.333333. action: 1.000000. mean reward 36.609028.
# World Perf: Episode 490.000000. Reward 53.666667. action: 1.000000. mean reward 36.545685.
# World Perf: Episode 493.000000. Reward 62.000000. action: 0.000000. mean reward 36.597614.
# World Perf: Episode 496.000000. Reward 48.000000. action: 1.000000. mean reward 36.451832.
# World Perf: Episode 499.000000. Reward 46.333333. action: 1.000000. mean reward 36.266632.
# World Perf: Episode 502.000000. Reward 51.000000. action: 1.000000. mean reward 36.162266.
# World Perf: Episode 505.000000. Reward 64.333333. action: 0.000000. mean reward 36.256847.
# World Perf: Episode 508.000000. Reward 50.000000. action: 1.000000. mean reward 36.176449.
# World Perf: Episode 511.000000. Reward 43.000000. action: 1.000000. mean reward 36.050446.
# World Perf: Episode 514.000000. Reward 74.000000. action: 0.000000. mean reward 36.185478.
# World Perf: Episode 517.000000. Reward 68.000000. action: 0.000000. mean reward 36.262035.
# World Perf: Episode 520.000000. Reward 57.333333. action: 0.000000. mean reward 36.226841.
# World Perf: Episode 523.000000. Reward 73.000000. action: 0.000000. mean reward 37.307064.
# World Perf: Episode 526.000000. Reward 65.333333. action: 1.000000. mean reward 41.196350.
# World Perf: Episode 529.000000. Reward 42.000000. action: 1.000000. mean reward 42.740917.
# World Perf: Episode 532.000000. Reward 55.000000. action: 0.000000. mean reward 42.681446.
# World Perf: Episode 535.000000. Reward 79.666667. action: 1.000000. mean reward 42.760391.
# World Perf: Episode 538.000000. Reward 98.000000. action: 1.000000. mean reward 42.966648.
# World Perf: Episode 541.000000. Reward 58.333333. action: 1.000000. mean reward 42.824249.
# World Perf: Episode 544.000000. Reward 55.333333. action: 0.000000. mean reward 42.683914.
# World Perf: Episode 547.000000. Reward 55.666667. action: 1.000000. mean reward 42.507954.
# 547

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
